# %%
import pandas as pd

# %%
df=pd.read_csv('MIT_dataset.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Date       1048575 non-null  str
#  1   Timestamp  1048575 non-null  str
#  2   Epoch      1048575 non-null  int64
#  3   Moteid     1048575 non-null  int64
#  4   Temp (C)   1048575 non-null  float64
#  5   Humidity   1048440 non-null  float64
#  6   Light      1048440 non-null  float64
#  7   Voltage    1025313 non-null  float64
# dtypes: float64(4), int64(2), str(2)
# memory usage: 64.0 MB

# %%
dfs=df.drop(['Date','Timestamp','Epoch','Moteid','Light','Voltage'],axis=1)

# %%
dfs.mean()
# Out:
# Temp (C)    40.069597
# Humidity    32.572495
# dtype: float64

# %%
dfs.var()
# Out:
# Temp (C)    1458.120771
# Humidity     361.460220
# dtype: float64

# %%
range=dfs.max()-dfs.min()
range
# Out:
# Temp (C)     160.553
# Humidity    9098.024
# dtype: float64
